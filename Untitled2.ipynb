# %% [markdown]
# <a href="https://colab.research.google.com/github/vanquoc12/Homework-Week-7/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import linear_model
url='/content/homework/passenger1.csv'
data=pd.read_csv(url)
data.hist()
plt.show()

# %%
sns.pairplot(data)

# %%
correlation=data.corr()
print(correlation)
# Out:
#              Passenger  Miles(X)  Dollars (Y)
# Passenger     1.000000  0.939166     0.980384
# Miles(X)      0.939166  1.000000     0.921729
# Dollars (Y)   0.980384  0.921729     1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='Miles(X)',y='Dollars (Y)',figsize=(9,9),color='purple')
# Out:
# <Axes: xlabel='Miles(X)', ylabel='Dollars (Y)'>

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import linear_model
data.plot(kind='scatter',x='Miles(X)',y='Dollars (Y)',figsize=(9,9),color='purple')
model=linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['Miles(X)']),y = data['Dollars (Y)'])
print('Giá trị intercept:',model.intercept_)
print('Giá trị coeffient:',model.coef_)
print('Độ chính xác:',model.score(X=pd.DataFrame(data['Miles(X)']),y=data['Dollars (Y)']))
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Giá trị intercept: 934.5366384552531
# Giá trị coeffient: [1.07802533]
# Độ chính xác: 0.8495847755547029

# %%
data.plot(kind='scatter',x='Miles(X)',y='Dollars (Y)',figsize=(9,9),color='black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['Miles(X)']))
plt.plot(data['Miles(X)'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['Miles(X)'],data['Dollars (Y)']**2]).T
model.fit(X,y=data['Dollars (Y)'])
print('Intercept là:',model.intercept_)
print('Coeficient là:',model.coef_)
print('Độ chính xác là:',model.score(X,y=data['Dollars (Y)']))
range = np.arange(1.5,7,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='Miles(X)',y='Dollars (Y)',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept là: 1847.9748101110904
# Coeficient là: [0.09215483 0.00010221]
# Độ chính xác là: 0.9782139450186861
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['Miles(X)'],data['Miles(X)']**2,data['Miles(X)']**3,data['Miles(X)']**4,data['Miles(X)']**5,data['Miles(X)']**6,data['Miles(X)']**7,data['Miles(X)']**8,data['Miles(X)']**9,data['Miles(X)']**10]).T
model.fit(X,y=data['Dollars (Y)'])
print('Intercept là:',model.intercept_)
print('Coeficient là:',model.coef_)
print('Độ chính xác là:',model.score(X,y=data['Dollars (Y)']))
range = np.arange(1.5,9,0.1)
X_range=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X = X_range)
data.plot(kind='scatter',x='Miles(X)',y='Dollars (Y)',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept là: 3384.909132160802
# Coeficient là: [-1.89202716e-06 -1.83641156e-03  1.30036504e-06 -2.84466745e-10
#   2.05648215e-14 -6.14945920e-18 -4.33680869e-18 -8.56519716e-18
#   5.20417043e-18  4.44522891e-18]
# Độ chính xác là: 0.9576092082144251
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import linear_model
url='/content/homework/Google_Stock_Price_Train.csv'
data=pd.read_csv(url)
data.head(2)
data.hist()
plt.show()

# %%
sns.pairplot(data)

# %%
correlation=data.corr()
print(correlation)
# Out:
#           Open      High       Low
# Open  1.000000  0.999692  0.999498
# High  0.999692  1.000000  0.999480
# Low   0.999498  0.999480  1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='High',y='Low',figsize=(9,9),color='black')
# Out:
# <Axes: xlabel='High', ylabel='Low'>

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['High']), y = data['Low'])
print('Giá trị intercept:',model.intercept_)
print('Giá trị coeffient:',model.coef_)
print('Độ chính xác:',model.score(X=pd.DataFrame(data['High']),y=data['Low']))
# Out:
# Giá trị intercept: 0.03601067370027522
# Giá trị coeffient: [0.98343716]
# Độ chính xác: 0.9989606735773059

# %%
data.plot(kind='scatter',x='High',y='Low',figsize=(9,9),color='black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['High']))
plt.plot(data['High'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['High'],data['High']**2]).T
model.fit(X,y=data['Low'])
print('Intercept là:',model.intercept_)
print('Coeficient là:',model.coef_)
print('Độ chính xác là:',model.score(X,y=data['Low']))
# Out:
# Intercept là: 2.5626691744063237
# Coeficient là: [9.73276437e-01 9.39723605e-06]
# Độ chính xác là: 0.9989626286138096

# %%
range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='High',y='Low',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import linear_model
url='/content/homework/abalone.csv'
data=pd.read_csv(url)
data.head(2)
data.hist()
plt.show()

# %%
sns.pairplot(data)

# %%
correlation=data.corr()
print(correlation)
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='Length',y='Height',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Length', ylabel='Height'>

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['Length']), y = data['Height'])
print('Giá trị intercept:',model.intercept_)
print('Giá trị coeffient:',model.coef_)
print('Độ chính xác:',model.score(X=pd.DataFrame(data['Length']),y=data['Height']))
# Out:
# Giá trị intercept: -0.01151275916171654
# Giá trị coeffient: [0.28822793]
# Độ chính xác: 0.6848449762972528

# %%
data.plot(kind='scatter',x='Length',y='Height',figsize=(9,9),color='black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['Length']))
plt.plot(data['Length'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['Length'],data['Height']**2]).T
model.fit(X,y=data['Height'])
print('Intercept là:',model.intercept_)
print('Coeficient là:',model.coef_)
print('Độ chính xác là:',model.score(X,y=data['Height']))
# Out:
# Intercept là: 0.005546924682313048
# Coeficient là: [0.21656453 0.96594029]
# Độ chính xác là: 0.9104492619437616

# %%
range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='Height',y='Length',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['Length'],data['Length']**2,data['Length']**3,data['Length']**4,data['Length']**5,data['Length']**6,data['Length']**7,data['Length']**8,data['Length']**9,data['Length']**10]).T
model.fit(X,y=data['Height'])
print('Intercept là:',model.intercept_)
print('Coeficient là:',model.coef_)
print('Độ chính xác là:',model.score(X,y=data['Height']))
# Out:
# Intercept là: -0.3534014528065679
# Coeficient là: [ 1.26795415e+01 -1.81053421e+02  1.44053385e+03 -6.97016251e+03
#   2.15604508e+04 -4.34279432e+04  5.65409918e+04 -4.57342224e+04
#   2.08179280e+04 -4.05621129e+03]
# Độ chính xác là: 0.6853364425818624

# %%
range = np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='Length',y='Height',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
